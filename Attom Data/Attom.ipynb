# %%
#Dependencies
import requests
import json
import pandas as pd
import numpy as np


base_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/school/districtdetail?id="
school_id = "5700086424"
url = base_url + school_id

# Attom API key
from config import attom_data
attom_data

r=requests.get(url, headers={"accept":"application/json","apikey":attom_data})
r
# Out:
# <Response [200]>

# %%
school_data = r.json()
school_data

#base_url2 = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/property/snapshot?postalcode=03768&minavmvalue=80000&maxavmvalue=200000"
#r2=requests.get(base_url2, headers={"accept":"application/json","apikey":attom_data})
#prop_data = r2.json()
# Out:
# {'status': {'version': '1.0.0',
#   'code': 0,
#   'msg': 'SuccessWithResult',
#   'total': 1,
#   'page': 1,
#   'pagesize': 10,
#   'responseDateTime': None,
#   'transactionID': None},
#  'school': [{'Identifier': {'Obdistrictnumber': '5700086424'},
#    'ProfilesAndTestScores': {'DistrictSummary': {'districttype': 'DISTRICT IN SUPERVISORY UNION',
#      'districtname': 'LYME SCHOOL DISTRICT',
#      'county3': '009',
#      'countyName': 'GRAFTON COUNTY',
#      'county': '33009',
#      'latitude': 43.811031,
#      'longitude': -72.159683,
#      'locationaddress': 'RTE 10',
#      'locationcity': 'LYME',
#      'fipsState': '33',
#      'stateabbrev': 'NH',
#      'zip54': '03768',
#      'zip': '03768',
#      'phone': '603-795-2125',
#      'startDate': '08/29',
#      'endDate': '06/15',
#      'GStestrating': 5},
#     'DistrictContact': {'Prefixliteral': 'Mr',
#      'Firstname': 'Jeff',
#      'Lastname': 'Valence',
#      'Gender': 'M',
#      'Englishtitle': 'Superintendent',
#      'Websiteurl': 'http://www.lymeschool.org'},
#     'DistrictDetail': {'educationClimateIndex': 'UNCLASSIFIED',
#      'advancedPlacement': 'N',
#      'beforeandafterschoolprgms': 'N',
#      'blueribbonschool': 'N',
#      'charterschools': 'N',
#      'bilingualeducation': 'N',
#      'giftedandtalented': 'N',
#      'internationbaccalaureate': 'N',
#      'magnetschool': 'N',
#      'sitebased': 'N',
#      'povertypercentage': 13.0,
#      'technologymeasuretext': None,
#      'totaldollarexpenditures': 2511000,
#      'instructionalexpensepupil': '$10,001+',
#      'AYPschools': 0,
#      'AYPschoolspercent': 0.0,
#      'NCLBschools': 0.0,
#      'NCLBschoolspercent': 0.0},
#     'DistrictSchoolInfo': {'Teachersprofessionalstaff': 25,
#      'Gradespancodedistricttext': None,
#      'Gradelevel1lotext': 'KINDERGARTEN',
#      'Gradelevel1hitext': '8TH GRADE',
#      'Numberofschools': 1,
#      'Countelementary': 0,
#      'Countmiddle': 0,
#      'Counthigh': 0,
#      'Voctech': 'N',
#      'Adulteducationclasses': 'N',
#      'Yearroundclasses': 'N',
#      'Studentsnumberof': 200,
#      'Studentsorvolumesdistrict': '100 - 299'},
#     'DistrictEnrollment': {'Enrollmentbygradeprek': 0,
#      'Enrollmentbygradekgtn': 0,
#      'Enrollmentbygradeone': 0,
#      'Enrollmentbygradetwo': 0,
#      'Enrollmentbygradethree': 0,
#      'Enrollmentbygradefour': 0,
#      'Enrollmentbygradefive': 0,
#      'Enrollmentbygradesix': 0,
#      'Enrollmentbygradeseven': 0,
#      'Enrollmentbygradeeight': 0,
#      'Enrollmentbygradenine': 0,
#      'Enrollmentbygradeten': 0,
#      'Enrollmentbygradeeleven': 0,
#      'Enrollmentbygradetwelve': 0,
#      'Enrollmentshift': 'No Change'},
#     'measurementresults': [{'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '3',
#       'measure': '53',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '3',
#       'measure': '71',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '4',
#       'measure': '78',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '4',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '5',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '5',
#       'measure': '74',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Science',
#       'grade': '5',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '6',
#       'measure': '80',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '6',
#       'measure': '80',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '7',
#       'measure': '83',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '7',
#       'measure': '78',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '8',
#       'measure': '89',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Science',
#       'grade': '8',
#       'measure': '66',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '8',
#       'measure': '77',
#       'insttype': 'District'}],
#     'measurementtype': [{'measureTypeId': 'NH01216',
#       'measuretype': 'Test',
#       'measureunits': 'Percent of Students',
#       'measurename': 'New Hampshire State Assessment System',
#       'measureabbrev': 'NH SAS',
#       'resulttype': 'Percent meeting expectations',
#       'scaledefinition': '% proficient',
#       'rankmax': '100',
#       'year': '2018',
#       'purposedescription': 'For more information about New Hampshire assessments, see the New Hampshire Department of Education'}],
#     'programs': [None]},
#    'Vintage': {'onboardDate': '2019-7-17'}}]}
