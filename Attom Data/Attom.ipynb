# %%
#Dependencies
import requests
import json
import pandas as pd
import numpy as np


base_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/school/districtdetail?id="
school_id = "5700086424"
url = base_url + school_id

# Attom API key
from config import attom_data
attom_data

r=requests.get(url, headers={"accept":"application/json","apikey":attom_data})
r
# Out:
# <Response [200]>

# %%
school_data = r.json()
school_data

#base_url2 = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/property/snapshot?postalcode=03768&minavmvalue=80000&maxavmvalue=200000"
#r2=requests.get(base_url2, headers={"accept":"application/json","apikey":attom_data})
#prop_data = r2.json()
# Out:
# {'status': {'version': '1.0.0',
#   'code': 0,
#   'msg': 'SuccessWithResult',
#   'total': 1,
#   'page': 1,
#   'pagesize': 10,
#   'responseDateTime': None,
#   'transactionID': None},
#  'school': [{'Identifier': {'Obdistrictnumber': '5700086424'},
#    'ProfilesAndTestScores': {'DistrictSummary': {'districttype': 'DISTRICT IN SUPERVISORY UNION',
#      'districtname': 'LYME SCHOOL DISTRICT',
#      'county3': '009',
#      'countyName': 'GRAFTON COUNTY',
#      'county': '33009',
#      'latitude': 43.811031,
#      'longitude': -72.159683,
#      'locationaddress': 'RTE 10',
#      'locationcity': 'LYME',
#      'fipsState': '33',
#      'stateabbrev': 'NH',
#      'zip54': '03768',
#      'zip': '03768',
#      'phone': '603-795-2125',
#      'startDate': '08/29',
#      'endDate': '06/15',
#      'GStestrating': 5},
#     'DistrictContact': {'Prefixliteral': 'Mr',
#      'Firstname': 'Jeff',
#      'Lastname': 'Valence',
#      'Gender': 'M',
#      'Englishtitle': 'Superintendent',
#      'Websiteurl': 'http://www.lymeschool.org'},
#     'DistrictDetail': {'educationClimateIndex': 'UNCLASSIFIED',
#      'advancedPlacement': 'N',
#      'beforeandafterschoolprgms': 'N',
#      'blueribbonschool': 'N',
#      'charterschools': 'N',
#      'bilingualeducation': 'N',
#      'giftedandtalented': 'N',
#      'internationbaccalaureate': 'N',
#      'magnetschool': 'N',
#      'sitebased': 'N',
#      'povertypercentage': 13.0,
#      'technologymeasuretext': None,
#      'totaldollarexpenditures': 2511000,
#      'instructionalexpensepupil': '$10,001+',
#      'AYPschools': 0,
#      'AYPschoolspercent': 0.0,
#      'NCLBschools': 0.0,
#      'NCLBschoolspercent': 0.0},
#     'DistrictSchoolInfo': {'Teachersprofessionalstaff': 25,
#      'Gradespancodedistricttext': None,
#      'Gradelevel1lotext': 'KINDERGARTEN',
#      'Gradelevel1hitext': '8TH GRADE',
#      'Numberofschools': 1,
#      'Countelementary': 0,
#      'Countmiddle': 0,
#      'Counthigh': 0,
#      'Voctech': 'N',
#      'Adulteducationclasses': 'N',
#      'Yearroundclasses': 'N',
#      'Studentsnumberof': 200,
#      'Studentsorvolumesdistrict': '100 - 299'},
#     'DistrictEnrollment': {'Enrollmentbygradeprek': 0,
#      'Enrollmentbygradekgtn': 0,
#      'Enrollmentbygradeone': 0,
#      'Enrollmentbygradetwo': 0,
#      'Enrollmentbygradethree': 0,
#      'Enrollmentbygradefour': 0,
#      'Enrollmentbygradefive': 0,
#      'Enrollmentbygradesix': 0,
#      'Enrollmentbygradeseven': 0,
#      'Enrollmentbygradeeight': 0,
#      'Enrollmentbygradenine': 0,
#      'Enrollmentbygradeten': 0,
#      'Enrollmentbygradeeleven': 0,
#      'Enrollmentbygradetwelve': 0,
#      'Enrollmentshift': 'No Change'},
#     'measurementresults': [{'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '3',
#       'measure': '53',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '3',
#       'measure': '71',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '4',
#       'measure': '78',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '4',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '5',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '5',
#       'measure': '74',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Science',
#       'grade': '5',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '6',
#       'measure': '80',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '6',
#       'measure': '80',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '7',
#       'measure': '83',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '7',
#       'measure': '78',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '8',
#       'measure': '89',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Science',
#       'grade': '8',
#       'measure': '66',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '8',
#       'measure': '77',
#       'insttype': 'District'}],
#     'measurementtype': [{'measureTypeId': 'NH01216',
#       'measuretype': 'Test',
#       'measureunits': 'Percent of Students',
#       'measurename': 'New Hampshire State Assessment System',
#       'measureabbrev': 'NH SAS',
#       'resulttype': 'Percent meeting expectations',
#       'scaledefinition': '% proficient',
#       'rankmax': '100',
#       'year': '2018',
#       'purposedescription': 'For more information about New Hampshire assessments, see the New Hampshire Department of Education'}],
#     'programs': [None]},
#    'Vintage': {'onboardDate': '2019-7-17'}}]}

# %%
#"name": "Sales (snapshot) by postal code",

base_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/sale/snapshot?postalcode=60409&page=1&pageSize=20"
s = requests.get(base_url, headers={"accept":"application/json", "apikey":attom_data})
s
# Out:
# <Response [200]>

# %%
sales_data = r.json()
sales_data
# Out:
# {'status': {'version': '1.0.0',
#   'code': 0,
#   'msg': 'SuccessWithResult',
#   'total': 7943,
#   'page': 1,
#   'pagesize': 20},
#  'property': [{'identifier': {'obPropId': 19879348510001,
#     'fips': '10001',
#     'apn': '30003600024000000',
#     'apnOrig': '30003600024000000',
#     'attomId': 198793485},
#    'lot': {'lotSize1': 66.67},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '454 MOUNT FRIENDSHIP RD',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '454 MOUNT FRIENDSHIP RD, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3872',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.230782',
#     'longitude': '-75.629613',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1093700, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19904'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'FARMS',
#     'yearbuilt': 1900,
#     'propLandUse': 'FARMS',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 7600},
#     'rooms': {'bathstotal': 6.0, 'beds': 12}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2015-8-21',
#     'saleTransDate': '2015-8-21',
#     'amount': {'saleamt': 775000,
#      'salerecdate': '2015-8-24',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000280798',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 64583, 'pricepersizeunit': 102}}},
#   {'identifier': {'obPropId': 14359436110001,
#     'fips': '10001',
#     'apn': '30003600022500000',
#     'apnOrig': '30003600022500000',
#     'attomId': 143594361},
#    'lot': {'lotSize1': 9.68},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '578 MOUNT FRIENDSHIP RD',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '578 MOUNT FRIENDSHIP RD, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3873',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.232232',
#     'longitude': '-75.630983',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1093700, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19904'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 1992,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 1956},
#     'rooms': {'bathstotal': 3.0, 'beds': 3}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2012-7-27',
#     'saleTransDate': '2012-7-27',
#     'amount': {'saleamt': 365000,
#      'salerecdate': '2012-7-30',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000214589',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 121667, 'pricepersizeunit': 187}}},
#   {'identifier': {'obPropId': 18905834910001,
#     'fips': '10001',
#     'apn': '30003600022602000',
#     'apnOrig': '30003600022602000',
#     'attomId': 189058349},
#    'lot': {'lotSize1': 3.8},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '696 MOUNT FRIENDSHIP RD',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '696 MOUNT FRIENDSHIP RD, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3874',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.233037',
#     'longitude': '-75.633161',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1093700, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 1991,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 2046},
#     'rooms': {'bathstotal': 3.0, 'beds': 3}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2006-4-3',
#     'saleTransDate': '2006-4-3',
#     'amount': {'saleamt': 360000,
#      'salerecdate': '2006-4-3',
#      'saledisclosuretype': 0,
#      'saledocnum': '0028470107',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 120000, 'pricepersizeunit': 176}}},
#   {'identifier': {'obPropId': 1689080010001,
#     'fips': '10001',
#     'apn': '30003600021301000',
#     'apnOrig': '30003600021301000',
#     'attomId': 16890800},
#    'lot': {'lotSize1': 3.95},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '885 MOUNT FRIENDSHIP RD',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '885 MOUNT FRIENDSHIP RD, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3880',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.235017',
#     'longitude': '-75.635235',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 2015,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 3062},
#     'rooms': {'bathstotal': 4.0, 'beds': 3}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2014-9-19',
#     'saleTransDate': '2014-9-19',
#     'amount': {'saleamt': 78000,
#      'salerecdate': '2014-10-8',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000263311',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 26000, 'pricepersizeunit': 25}}},
#   {'identifier': {'obPropId': 19380350310001,
#     'fips': '10001',
#     'apn': '30003600021332000',
#     'apnOrig': '30003600021332000',
#     'attomId': 193803503},
#    'lot': {'lotSize1': 2.0},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '201 KEENE LN',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '201 KEENE LN, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3877',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.235454',
#     'longitude': '-75.643312',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'RESIDENTIAL',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 0,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 0},
#     'rooms': {'bathstotal': 0.0, 'beds': 0}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2008-1-14',
#     'saleTransDate': '2008-1-14',
#     'amount': {'saleamt': 20000,
#      'salerecdate': '2008-1-15',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000113303',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 0, 'pricepersizeunit': 0}}},
#   {'identifier': {'obPropId': 19481080310001,
#     'fips': '10001',
#     'apn': '30003600021326000',
#     'apnOrig': '30003600021326000',
#     'attomId': 194810803},
#    'lot': {'lotSize1': 2.0},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '68 LENORA DR',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '68 LENORA DR, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3864',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.236177',
#     'longitude': '-75.641531',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 2008,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 3975},
#     'rooms': {'bathstotal': 4.0, 'beds': 4}},
#    'vintage': {'lastModified': '2018-9-28', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2018-8-27',
#     'saleTransDate': '2018-8-27',
#     'amount': {'saleamt': 520000,
#      'salecode': 'Estimated Sale Price',
#      'salerecdate': '2018-9-4',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000347251',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 130000, 'pricepersizeunit': 131}}},
#   {'identifier': {'obPropId': 2757587310001,
#     'fips': '10001',
#     'apn': '30003600021300000',
#     'apnOrig': '30003600021300000',
#     'attomId': 27575873},
#    'lot': {'lotSize1': 13.7},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '263 SMOKEY LN',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '263 SMOKEY LN, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3862',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.236722',
#     'longitude': '-75.646770',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 2000,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 1056},
#     'rooms': {'bathstotal': 0.0, 'beds': 0}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2007-12-10',
#     'saleTransDate': '2007-12-10',
#     'amount': {'saleamt': 140500,
#      'salerecdate': '2008-5-22',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000123555',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 0, 'pricepersizeunit': 133}}},
#   {'identifier': {'obPropId': 18905829110001,
#     'fips': '10001',
#     'apn': '30003600021700000',
#     'apnOrig': '30003600021700000',
#     'attomId': 189058291},
#    'lot': {'lotSize1': 1.03},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '1009 MOUNT FRIENDSHIP RD',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '1009 MOUNT FRIENDSHIP RD, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3878',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.236761',
#     'longitude': '-75.635548',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 1978,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 1188},
#     'rooms': {'bathstotal': 1.0, 'beds': 3}},
#    'vintage': {'lastModified': '2018-12-7', 'pubDate': '2018-12-7'},
#    'sale': {'salesearchdate': '2018-11-21',
#     'saleTransDate': '2018-11-21',
#     'amount': {'saleamt': 0,
#      'salerecdate': '2018-11-21',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000352154',
#      'saletranstype': 'Nominal - Non/Arms Length Sale'},
#     'calculation': {'priceperbed': 0, 'pricepersizeunit': 0}}},
#   {'identifier': {'obPropId': 20698921010001,
#     'fips': '10001',
#     'apn': '30003600021323000',
#     'apnOrig': '30003600021323000',
#     'attomId': 206989210},
#    'lot': {'lotSize1': 2.0},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '60 FORTUNE WAY',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '60 FORTUNE WAY, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3855',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.236877',
#     'longitude': '-75.645821',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 1999,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 1456},
#     'rooms': {'bathstotal': 0.0, 'beds': 0}},
#    'vintage': {'lastModified': '2018-6-22', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2018-6-1',
#     'saleTransDate': '2018-6-1',
#     'amount': {'saleamt': 170000,
#      'salerecdate': '2018-6-4',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000341767',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 0, 'pricepersizeunit': 117}}},
#   {'identifier': {'obPropId': 19380350210001,
#     'fips': '10001',
#     'apn': '30003600021330000',
#     'apnOrig': '30003600021330000',
#     'attomId': 193803502},
#    'lot': {'lotSize1': 2.3},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '157 LENORA DR',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '157 LENORA DR, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3865',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.237147',
#     'longitude': '-75.641462',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 2002,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 2125},
#     'rooms': {'bathstotal': 3.0, 'beds': 4}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2016-6-24',
#     'saleTransDate': '2016-6-24',
#     'amount': {'saleamt': 324500,
#      'salerecdate': '2016-6-28',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000298662',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 81125, 'pricepersizeunit': 153}}},
#   {'identifier': {'obPropId': 19462615510001,
#     'fips': '10001',
#     'apn': '30003600021317000',
#     'apnOrig': '30003600021317000',
#     'attomId': 194626155},
#    'lot': {'lotSize1': 1.5},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '1990 BRYN ZION RD',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '1990 BRYN ZION RD, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3825',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.237403',
#     'longitude': '-75.642105',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 2012,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 2624},
#     'rooms': {'bathstotal': 3.0, 'beds': 3}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2014-12-8',
#     'saleTransDate': '2014-12-8',
#     'amount': {'saleamt': 0,
#      'salerecdate': '2014-12-11',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000266822',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 0, 'pricepersizeunit': 0}}},
#   {'identifier': {'obPropId': 2381507310001,
#     'fips': '10001',
#     'apn': '30003600021313000',
#     'apnOrig': '30003600021313000',
#     'attomId': 23815073},
#    'lot': {'lotSize1': 16.6},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '2284 BRYN ZION RD',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '2284 BRYN ZION RD, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3895',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.237629',
#     'longitude': '-75.639736',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'FARMS',
#     'yearbuilt': 1997,
#     'propLandUse': 'FARMS',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 3228},
#     'rooms': {'bathstotal': 4.0, 'beds': 3}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2015-12-16',
#     'saleTransDate': '2015-12-16',
#     'amount': {'saleamt': 560000,
#      'salerecdate': '2016-1-7',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000288747',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 186667, 'pricepersizeunit': 173}}},
#   {'identifier': {'obPropId': 2381507210001,
#     'fips': '10001',
#     'apn': '30003600021311000',
#     'apnOrig': '30003600021311000',
#     'attomId': 23815072},
#    'lot': {'lotSize1': 1.0},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '2228 BRYN ZION RD',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '2228 BRYN ZION RD, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3895',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.237741',
#     'longitude': '-75.638757',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 1995,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 1784},
#     'rooms': {'bathstotal': 2.0, 'beds': 3}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2013-6-5',
#     'saleTransDate': '2013-6-5',
#     'amount': {'saleamt': 240000,
#      'salerecdate': '2013-6-7',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000235983',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 80000, 'pricepersizeunit': 135}}},
#   {'identifier': {'obPropId': 2046278710001,
#     'fips': '10001',
#     'apn': '30003600021307000',
#     'apnOrig': '30003600021307000',
#     'attomId': 20462787},
#    'lot': {'lotSize1': 1.0},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '1884 BRYN ZION RD',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '1884 BRYN ZION RD, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3824',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.237765',
#     'longitude': '-75.644941',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 1997,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 1568},
#     'rooms': {'bathstotal': 2.0, 'beds': 3}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2008-7-31',
#     'saleTransDate': '2008-7-31',
#     'amount': {'saleamt': 244000,
#      'salerecdate': '2008-8-5',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000129066',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 81333, 'pricepersizeunit': 156}}},
#   {'identifier': {'obPropId': 3092220510001,
#     'fips': '10001',
#     'apn': '30003600021310000',
#     'apnOrig': '30003600021310000',
#     'attomId': 30922205},
#    'lot': {'lotSize1': 3.0},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '2180 BRYN ZION RD',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '2180 BRYN ZION RD, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3800',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.237838',
#     'longitude': '-75.637918',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 1995,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 1976},
#     'rooms': {'bathstotal': 2.0, 'beds': 3}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2007-6-13',
#     'saleTransDate': '2007-6-13',
#     'amount': {'saleamt': 258000,
#      'salerecdate': '2007-6-28',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000095762',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 86000, 'pricepersizeunit': 131}}},
#   {'identifier': {'obPropId': 18185173810001,
#     'fips': '10001',
#     'apn': '30003603011900000',
#     'apnOrig': '30003603011900000',
#     'attomId': 181851738},
#    'lot': {'lotSize1': 0.51},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '22 ZION DR',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '22 ZION DR, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '6800',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.237843',
#     'longitude': '-75.641583',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, RS0000338140, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 2010,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 4008},
#     'rooms': {'bathstotal': 3.0, 'beds': 4}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2010-12-30',
#     'saleTransDate': '2010-12-30',
#     'amount': {'saleamt': 432758,
#      'salerecdate': '2011-2-16',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000184858',
#      'saletranstype': 'New Construction'},
#     'calculation': {'priceperbed': 108190, 'pricepersizeunit': 108}}},
#   {'identifier': {'obPropId': 19539459410001,
#     'fips': '10001',
#     'apn': '30003603012000000',
#     'apnOrig': '30003603012000000',
#     'attomId': 195394594},
#    'lot': {'lotSize1': 0.54},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '23 ZION DR',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '23 ZION DR, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '6807',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.237859',
#     'longitude': '-75.641937',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, RS0000338140, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 2006,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 4074},
#     'rooms': {'bathstotal': 4.0, 'beds': 4}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2007-2-23',
#     'saleTransDate': '2007-2-23',
#     'amount': {'saleamt': 440667,
#      'salerecdate': '2007-3-1',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000084159',
#      'saletranstype': 'New Construction'},
#     'calculation': {'priceperbed': 110167, 'pricepersizeunit': 108}}},
#   {'identifier': {'obPropId': 5143274810001,
#     'fips': '10001',
#     'apn': '30003600021306000',
#     'apnOrig': '30003600021306000',
#     'attomId': 51432748},
#    'lot': {'lotSize1': 1.0},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '1852 BRYN ZION RD',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '1852 BRYN ZION RD, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '3824',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.237956',
#     'longitude': '-75.647290',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 2001,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 1536},
#     'rooms': {'bathstotal': 2.0, 'beds': 3}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2005-4-27',
#     'saleTransDate': '2005-4-27',
#     'amount': {'saleamt': 215000,
#      'salerecdate': '2005-4-27',
#      'saledisclosuretype': 0,
#      'saledocnum': '0020030121',
#      'saletranstype': 'Resale'},
#     'calculation': {'priceperbed': 71667, 'pricepersizeunit': 140}}},
#   {'identifier': {'obPropId': 21911973710001,
#     'fips': '10001',
#     'apn': '30003603011800000',
#     'apnOrig': '30003603011800000',
#     'attomId': 219119737},
#    'lot': {'lotSize1': 0.54},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '40 ZION DR',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '40 ZION DR, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '6800',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.238112',
#     'longitude': '-75.641591',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, RS0000338140, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 2013,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 3919},
#     'rooms': {'bathstotal': 5.0, 'beds': 4}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2013-8-28',
#     'saleTransDate': '2013-8-28',
#     'amount': {'saleamt': 344500,
#      'salerecdate': '2013-9-6',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000242481',
#      'saletranstype': 'New Construction'},
#     'calculation': {'priceperbed': 86125, 'pricepersizeunit': 88}}},
#   {'identifier': {'obPropId': 2046276810001,
#     'fips': '10001',
#     'apn': '30003603012100000',
#     'apnOrig': '30003603012100000',
#     'attomId': 20462768},
#    'lot': {'lotSize1': 0.51},
#    'address': {'country': 'US',
#     'countrySubd': 'DE',
#     'line1': '43 ZION DR',
#     'line2': 'SMYRNA, DE 19977',
#     'locality': 'Smyrna',
#     'matchCode': 'ExaStr',
#     'oneLine': '43 ZION DR, SMYRNA, DE 19977',
#     'postal1': '19977',
#     'postal2': '6807',
#     'postal3': 'R002'},
#    'location': {'accuracy': 'Street',
#     'elevation': 0.0,
#     'latitude': '39.238153',
#     'longitude': '-75.641947',
#     'distance': 0.0,
#     'geoid': 'CO10001, CS1091480, DB1001620, MT30001363, RS0000338140, SB0000077305, SB0000077306, SB0000077308, SB0000077309, ZI19977'},
#    'summary': {'propclass': 'Agricultural',
#     'propsubtype': 'HOUSE',
#     'proptype': 'AGRICULTURAL (NEC)',
#     'yearbuilt': 2006,
#     'propLandUse': 'AGRICULTURAL (NEC)',
#     'propIndicator': '70'},
#    'building': {'size': {'universalsize': 3041},
#     'rooms': {'bathstotal': 4.0, 'beds': 4}},
#    'vintage': {'lastModified': '2018-1-27', 'pubDate': '2019-8-11'},
#    'sale': {'salesearchdate': '2007-1-19',
#     'saleTransDate': '2007-1-19',
#     'amount': {'saleamt': 363467,
#      'salerecdate': '2007-1-31',
#      'saledisclosuretype': 0,
#      'saledocnum': '0000081109',
#      'saletranstype': 'New Construction'},
#     'calculation': {'priceperbed': 90867, 'pricepersizeunit': 120}}}]}

# %%
# School detail
sd_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/school/detail?id=00582204"
    
#sd = requests.get(base_url, headers={"accept":"application/json", "apikey":attom_data})
sd = requests.get(base_url, headers={"Accept":"application/json", "apikey":attom_data})
sd
# Out:
# <Response [400]>

# %%
school_detail = s.json()
school_detail
# Out:
# {'status': {'version': '1.0.0',
#   'code': -5,
#   'msg': 'Invalid Parameter in Request',
#   'total': 0,
#   'page': 0,
#   'pagesize': 0}}
