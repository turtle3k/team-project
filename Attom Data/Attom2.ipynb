# %% [markdown]
# # Notebook for data gathering
# ## Setting up dependencies, keys and such

# %%
#Dependencies
import requests
import json
import pandas as pd
import numpy as np
from pprint import pprint

# Attom API key
from config import attom_data

# %% [markdown]
# ## Testing out the APIs, looking and results, seeing what we want/need

# %%
# Testing out an API - for school district info
base_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/school/districtdetail?id="
school_id = "5700086424"
url = base_url + school_id
r=requests.get(url, headers={"accept":"application/json","apikey":attom_data})
r
# Out:
# <Response [200]>

# %%
# Looking at the JSON data for school data we get back so we can decide what we need
school_data = r.json()
school_data
# Out:
# {'status': {'version': '1.0.0',
#   'code': 0,
#   'msg': 'SuccessWithResult',
#   'total': 1,
#   'page': 1,
#   'pagesize': 10,
#   'responseDateTime': None,
#   'transactionID': None},
#  'school': [{'Identifier': {'Obdistrictnumber': '5700086424'},
#    'ProfilesAndTestScores': {'DistrictSummary': {'districttype': 'DISTRICT IN SUPERVISORY UNION',
#      'districtname': 'LYME SCHOOL DISTRICT',
#      'county3': '009',
#      'countyName': 'GRAFTON COUNTY',
#      'county': '33009',
#      'latitude': 43.811031,
#      'longitude': -72.159683,
#      'locationaddress': 'RTE 10',
#      'locationcity': 'LYME',
#      'fipsState': '33',
#      'stateabbrev': 'NH',
#      'zip54': '03768',
#      'zip': '03768',
#      'phone': '603-795-2125',
#      'startDate': '08/29',
#      'endDate': '06/15',
#      'GStestrating': 5},
#     'DistrictContact': {'Prefixliteral': 'Mr',
#      'Firstname': 'Jeff',
#      'Lastname': 'Valence',
#      'Gender': 'M',
#      'Englishtitle': 'Superintendent',
#      'Websiteurl': 'http://www.lymeschool.org'},
#     'DistrictDetail': {'educationClimateIndex': 'UNCLASSIFIED',
#      'advancedPlacement': 'N',
#      'beforeandafterschoolprgms': 'N',
#      'blueribbonschool': 'N',
#      'charterschools': 'N',
#      'bilingualeducation': 'N',
#      'giftedandtalented': 'N',
#      'internationbaccalaureate': 'N',
#      'magnetschool': 'N',
#      'sitebased': 'N',
#      'povertypercentage': 13.0,
#      'technologymeasuretext': None,
#      'totaldollarexpenditures': 2511000,
#      'instructionalexpensepupil': '$10,001+',
#      'AYPschools': 0,
#      'AYPschoolspercent': 0.0,
#      'NCLBschools': 0.0,
#      'NCLBschoolspercent': 0.0},
#     'DistrictSchoolInfo': {'Teachersprofessionalstaff': 25,
#      'Gradespancodedistricttext': None,
#      'Gradelevel1lotext': 'KINDERGARTEN',
#      'Gradelevel1hitext': '8TH GRADE',
#      'Numberofschools': 1,
#      'Countelementary': 0,
#      'Countmiddle': 0,
#      'Counthigh': 0,
#      'Voctech': 'N',
#      'Adulteducationclasses': 'N',
#      'Yearroundclasses': 'N',
#      'Studentsnumberof': 200,
#      'Studentsorvolumesdistrict': '100 - 299'},
#     'DistrictEnrollment': {'Enrollmentbygradeprek': 0,
#      'Enrollmentbygradekgtn': 0,
#      'Enrollmentbygradeone': 0,
#      'Enrollmentbygradetwo': 0,
#      'Enrollmentbygradethree': 0,
#      'Enrollmentbygradefour': 0,
#      'Enrollmentbygradefive': 0,
#      'Enrollmentbygradesix': 0,
#      'Enrollmentbygradeseven': 0,
#      'Enrollmentbygradeeight': 0,
#      'Enrollmentbygradenine': 0,
#      'Enrollmentbygradeten': 0,
#      'Enrollmentbygradeeleven': 0,
#      'Enrollmentbygradetwelve': 0,
#      'Enrollmentshift': 'No Change'},
#     'measurementresults': [{'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '3',
#       'measure': '53',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '3',
#       'measure': '71',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '4',
#       'measure': '78',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '4',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '5',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '5',
#       'measure': '74',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Science',
#       'grade': '5',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '6',
#       'measure': '80',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '6',
#       'measure': '80',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '7',
#       'measure': '83',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '7',
#       'measure': '78',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '8',
#       'measure': '89',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Science',
#       'grade': '8',
#       'measure': '66',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '8',
#       'measure': '77',
#       'insttype': 'District'}],
#     'measurementtype': [{'measureTypeId': 'NH01216',
#       'measuretype': 'Test',
#       'measureunits': 'Percent of Students',
#       'measurename': 'New Hampshire State Assessment System',
#       'measureabbrev': 'NH SAS',
#       'resulttype': 'Percent meeting expectations',
#       'scaledefinition': '% proficient',
#       'rankmax': '100',
#       'year': '2018',
#       'purposedescription': 'For more information about New Hampshire assessments, see the New Hampshire Department of Education'}],
#     'programs': [None]},
#    'Vintage': {'onboardDate': '2019-7-17'}}]}

# %%
# Testing out an API for sales info
#"name": "Sales (snapshot) by postal code",

base_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/sale/snapshot?postalcode=63123&page=1&pageSize=20"
s = requests.get(base_url, headers={"accept":"application/json", "apikey":attom_data})
s
# Out:
# <Response [200]>

# %%
#Looking at the JSON data for sales data
sales_data = r.json()
sales_data
# Out:
# {'status': {'version': '1.0.0',
#   'code': 0,
#   'msg': 'SuccessWithResult',
#   'total': 1,
#   'page': 1,
#   'pagesize': 10,
#   'responseDateTime': None,
#   'transactionID': None},
#  'school': [{'Identifier': {'Obdistrictnumber': '5700086424'},
#    'ProfilesAndTestScores': {'DistrictSummary': {'districttype': 'DISTRICT IN SUPERVISORY UNION',
#      'districtname': 'LYME SCHOOL DISTRICT',
#      'county3': '009',
#      'countyName': 'GRAFTON COUNTY',
#      'county': '33009',
#      'latitude': 43.811031,
#      'longitude': -72.159683,
#      'locationaddress': 'RTE 10',
#      'locationcity': 'LYME',
#      'fipsState': '33',
#      'stateabbrev': 'NH',
#      'zip54': '03768',
#      'zip': '03768',
#      'phone': '603-795-2125',
#      'startDate': '08/29',
#      'endDate': '06/15',
#      'GStestrating': 5},
#     'DistrictContact': {'Prefixliteral': 'Mr',
#      'Firstname': 'Jeff',
#      'Lastname': 'Valence',
#      'Gender': 'M',
#      'Englishtitle': 'Superintendent',
#      'Websiteurl': 'http://www.lymeschool.org'},
#     'DistrictDetail': {'educationClimateIndex': 'UNCLASSIFIED',
#      'advancedPlacement': 'N',
#      'beforeandafterschoolprgms': 'N',
#      'blueribbonschool': 'N',
#      'charterschools': 'N',
#      'bilingualeducation': 'N',
#      'giftedandtalented': 'N',
#      'internationbaccalaureate': 'N',
#      'magnetschool': 'N',
#      'sitebased': 'N',
#      'povertypercentage': 13.0,
#      'technologymeasuretext': None,
#      'totaldollarexpenditures': 2511000,
#      'instructionalexpensepupil': '$10,001+',
#      'AYPschools': 0,
#      'AYPschoolspercent': 0.0,
#      'NCLBschools': 0.0,
#      'NCLBschoolspercent': 0.0},
#     'DistrictSchoolInfo': {'Teachersprofessionalstaff': 25,
#      'Gradespancodedistricttext': None,
#      'Gradelevel1lotext': 'KINDERGARTEN',
#      'Gradelevel1hitext': '8TH GRADE',
#      'Numberofschools': 1,
#      'Countelementary': 0,
#      'Countmiddle': 0,
#      'Counthigh': 0,
#      'Voctech': 'N',
#      'Adulteducationclasses': 'N',
#      'Yearroundclasses': 'N',
#      'Studentsnumberof': 200,
#      'Studentsorvolumesdistrict': '100 - 299'},
#     'DistrictEnrollment': {'Enrollmentbygradeprek': 0,
#      'Enrollmentbygradekgtn': 0,
#      'Enrollmentbygradeone': 0,
#      'Enrollmentbygradetwo': 0,
#      'Enrollmentbygradethree': 0,
#      'Enrollmentbygradefour': 0,
#      'Enrollmentbygradefive': 0,
#      'Enrollmentbygradesix': 0,
#      'Enrollmentbygradeseven': 0,
#      'Enrollmentbygradeeight': 0,
#      'Enrollmentbygradenine': 0,
#      'Enrollmentbygradeten': 0,
#      'Enrollmentbygradeeleven': 0,
#      'Enrollmentbygradetwelve': 0,
#      'Enrollmentshift': 'No Change'},
#     'measurementresults': [{'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '3',
#       'measure': '53',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '3',
#       'measure': '71',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '4',
#       'measure': '78',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '4',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '5',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '5',
#       'measure': '74',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Science',
#       'grade': '5',
#       'measure': '61',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '6',
#       'measure': '80',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '6',
#       'measure': '80',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '7',
#       'measure': '83',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '7',
#       'measure': '78',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Reading',
#       'grade': '8',
#       'measure': '89',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Science',
#       'grade': '8',
#       'measure': '66',
#       'insttype': 'District'},
#      {'measureTypeId': 'NH01216',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '8',
#       'measure': '77',
#       'insttype': 'District'}],
#     'measurementtype': [{'measureTypeId': 'NH01216',
#       'measuretype': 'Test',
#       'measureunits': 'Percent of Students',
#       'measurename': 'New Hampshire State Assessment System',
#       'measureabbrev': 'NH SAS',
#       'resulttype': 'Percent meeting expectations',
#       'scaledefinition': '% proficient',
#       'rankmax': '100',
#       'year': '2018',
#       'purposedescription': 'For more information about New Hampshire assessments, see the New Hampshire Department of Education'}],
#     'programs': [None]},
#    'Vintage': {'onboardDate': '2019-7-17'}}]}

# %%
# Another API - for school detail
# School detail - curl -X GET --header 'Accept: application/json' --header 'apikey: 736f1130096aa92549d800921bca8e8c' 'https://api.gateway.attomdata.com/propertyapi/v1.0.0/school/detail?id=00582204'
sd_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/school/detail?id=00582204"

#sd = requests.get(base_url, headers={"accept":"application/json", "apikey":attom_data})
sd = requests.get(sd_url, headers={"Accept":"application/json", "apikey":attom_data})
sd
# Out:
# <Response [200]>

# %%
# Looking at the JSON data for school detail
school_detail = sd.json()
school_detail
# Out:
# {'status': {'version': '1.0.0',
#   'code': 0,
#   'msg': 'SuccessWithResult',
#   'total': 1,
#   'page': 1,
#   'pagesize': 10,
#   'responseDateTime': None,
#   'transactionID': None},
#  'school': [{'Identifier': {'OBInstID': '00582204'},
#    'SchoolProfileAndDistrictInfo': {'SchoolLocation': {'COUNTY3': '510',
#      'COUNTYNAME': 'ST. LOUIS CITY',
#      'COUNTY': '29510',
#      'geocodinglatitude': 38.610114,
#      'geocodinglongitude': -90.218684,
#      'locationaddress': '2156 RUSSELL BLVD',
#      'locationcity': 'SAINT LOUIS',
#      'fipsState': '29',
#      'stateabbrev': 'MO',
#      'zip54': '63104-2607',
#      'ZIP': '63104',
#      'Obdistrictnumber': '2900580749',
#      'districttype': 'REGULAR LOCAL SCHOOL DISTRICT',
#      'districtname': 'ST. LOUIS PUBLIC SCHOOLS',
#      'geoid': None},
#     'SchoolSummary': {'Filetypetext': 'PUBLIC',
#      'buildingtypetext': 'REGULAR SCHOOL',
#      'institutionname': 'MCKINLEY CLASS. LEADERSHIP AC.',
#      'startDate': '08/13',
#      'endDate': '05/21',
#      'gradelevel1lotext': '6TH GRADE',
#      'gradelevel1hitext': '12TH GRADE',
#      'gradelevel1locode': '06',
#      'gradelevel1hicode': '12',
#      'gradespancodebldgtext': '6-12',
#      'Preschool': None,
#      'Elementary': None,
#      'Middle': 'Y',
#      'High': 'Y',
#      'GStestrating': 5},
#     'SchoolContact': {'phone': '314-773-0027',
#      'Prefixliteral': 'Mr',
#      'Firstname': 'Stephen',
#      'Lastname': 'Warmack',
#      'Gender': 'M',
#      'Englishtitle': 'Principal',
#      'Websiteurl': 'http://www.slps.org/Domain/2997'},
#     'SchoolDetail': {'educationClimateIndex': 'AVERAGE',
#      'advancedPlacement': 'Y',
#      'beforeandafterschoolprgms': 'Y',
#      'blueribbonschool': 'N',
#      'charterschools': 'N',
#      'giftedandtalented': 'Y',
#      'internationbaccalaureate': 'N',
#      'magnetschool': 'N',
#      'sitebased': 'Y',
#      'collegebound': 92,
#      'voctech': 'Y',
#      'adulteducationclasses': 'N',
#      'adultother': None,
#      'specialeducation': 'Y',
#      'alterantiveprogram': 'N',
#      'yearroundclasses': 'N',
#      'ESL': 'N',
#      'Povertylevel': '30 PERCENT OR MORE',
#      'Instructionalexpensepupil': 7305,
#      'AYPschool': 'Y'},
#     'SchoolTech': {'Technologymeasuretype': 'HIGH',
#      'Computergrandtotal': 100,
#      'OStype': 'W'},
#     'SchoolEnrollment': {'Enrollmentbygradeprek': 0,
#      'Enrollmentbygradekgtn': 0,
#      'Enrollmentbygradeone': 0,
#      'Enrollmentbygradetwo': 0,
#      'Enrollmentbygradethree': 0,
#      'Enrollmentbygradefour': 0,
#      'Enrollmentbygradefive': 0,
#      'Enrollmentbygradesix': 115,
#      'Enrollmentbygradeseven': 99,
#      'Enrollmentbygradeeight': 99,
#      'Enrollmentbygradenine': 92,
#      'Enrollmentbygradeten': 86,
#      'Enrollmentbygradeeleven': 70,
#      'Enrollmentbygradetwelve': 40,
#      'Enrollmentshift': '-20% to -50%',
#      'Studentsnumberof': 600,
#      'Studentsgrade': 85.0,
#      'Studentteacher': '11'},
#     'DistrictSummary': {'Obdistrictnumber': '2900580749',
#      'districttype': 'REGULAR LOCAL SCHOOL DISTRICT',
#      'districtname': 'ST. LOUIS CITY SCHOOL DISTRICT',
#      'COUNTY3': '510',
#      'COUNTYNAME': 'ST. LOUIS CITY',
#      'COUNTY': '29510',
#      'latitude': 38.632909,
#      'longitude': -90.194594,
#      'locationaddress': '801 N 11TH ST',
#      'locationcity': 'SAINT LOUIS',
#      'fipsState': '29',
#      'stateabbrev': 'MO',
#      'zip54': '63101-1015',
#      'ZIP': '63101',
#      'phone': '314-231-3720',
#      'startDate': '08/13',
#      'endDate': '05/21',
#      'GStestrating': 3},
#     'DistrictContact': {'Prefixliteral': 'Dr',
#      'Firstname': 'Kelvin',
#      'Lastname': 'Adams',
#      'Gender': 'U',
#      'Englishtitle': 'Superintendent',
#      'Websiteurl': 'http://www.slps.org'},
#     'MeasurementResults': [{'measureTypeId': 'MO00041',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '6',
#       'measure': '83.3',
#       'insttype': 'School'},
#      {'measureTypeId': 'MO00041',
#       'year': '2018',
#       'subjectName': 'Communication Arts',
#       'grade': '6',
#       'measure': '84.4',
#       'insttype': 'School'},
#      {'measureTypeId': 'MO00041',
#       'year': '2018',
#       'subjectName': 'Communication Arts',
#       'grade': '7',
#       'measure': '84.9',
#       'insttype': 'School'},
#      {'measureTypeId': 'MO00041',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '7',
#       'measure': '62.1',
#       'insttype': 'School'},
#      {'measureTypeId': 'MO00041',
#       'year': '2018',
#       'subjectName': 'Mathematics',
#       'grade': '8',
#       'measure': '55.8',
#       'insttype': 'School'},
#      {'measureTypeId': 'MO00041',
#       'year': '2018',
#       'subjectName': 'Communication Arts',
#       'grade': '8',
#       'measure': '84.5',
#       'insttype': 'School'},
#      {'measureTypeId': 'MO00041',
#       'year': '2018',
#       'subjectName': 'Government',
#       'grade': 'EOC',
#       'measure': '93.4',
#       'insttype': 'School'},
#      {'measureTypeId': 'MO00041',
#       'year': '2018',
#       'subjectName': 'English II',
#       'grade': 'EOC',
#       'measure': '86.6',
#       'insttype': 'School'},
#      {'measureTypeId': 'MO00041',
#       'year': '2018',
#       'subjectName': 'Algebra I',
#       'grade': 'EOC',
#       'measure': '79.7',
#       'insttype': 'School'},
#      {'measureTypeId': 'MO00041',
#       'year': '2018',
#       'subjectName': 'Algebra II',
#       'grade': 'EOC',
#       'measure': '60.9',
#       'insttype': 'School'}],
#     'MeasurementType': [{'measureTypeId': 'MO00041',
#       'measuretype': 'Test',
#       'measureunits': 'Percent of Students',
#       'measurename': 'Missouri Assessment Program',
#       'measureabbrev': 'MAP',
#       'resulttype': 'Percent meeting expectations',
#       'scaledefinition': '% proficient or better',
#       'rankmax': '100',
#       'year': '2018',
#       'purposedescription': 'The Assessment section provides professional services related to the Missouri Assessment Program (MAP) and the National Assessment of Educational Progress (NAEP).'}],
#     'Programs': ['Computer Science - General',
#      'Foreign Language - Spanish',
#      'Vocational Education - Accounting',
#      'English - English / Language Arts',
#      'Special Education - Early Childhood Special Needs',
#      'Social Studies / Social Sciences - Social Studies / Social Sciences']},
#    'Vintage': {'onboardDate': '2019-7-17'}}]}

# %% [markdown]
# ## Runing the APIs to get our data
# ####  Note: we found from the doc and experimenting that we'd need an OBInstID for each school to get detail info.
# ####             We needed lat & lng info to get OBInstID -  see School_zips Jupyter notebook for zips to lat, lng using Google API
# ####             We gathered those OBInstIDs doing manual lookups on the ATTOM API website (there were multiple schools per zip)
# ####             Similar process for Real Estate sales info - there were numerous GeoIDs per zip, until we realized ZI##### worked
# ####             A "final" spreadsheet with zip, lat, lng, OBInstID and GeoID was created to use as a source for our ATTOM API calls
#
# ### Start with the School detail

# %%
# Import the csv file with OBInstID s in it to run with the school detail API
latlon_df = pd.read_csv("../Data/school_zip_lat_long2.csv", usecols=[0,1,3,4,5,6,7])
print(latlon_df.dtypes)
latlon_df.head()
# Out:
# Zip Codes            int64
# Areas               object
# Latitude           float64
# Longitude          float64
# School District     object
# OBInstlD             int64
# GeoID               object
# dtype: object
#    Zip Codes                    Areas   Latitude  Longitude  \
# 0      63123                   Affton  38.558084 -90.327783
# 1      63011                  Ballwin  38.604451 -90.558879
# 2      63021                  Ballwin  38.557323 -90.535236
# 3      63137  Bellefontaine Neighbors  38.747943 -90.211357
# 4      63118              Benton Park  38.595062 -90.229156
#
#                      School District  OBInstlD    GeoID
# 0                 AFFTON HIGH SCHOOL    577405  ZI63123
# 1                   WEST HIGH SCHOOL    579439  ZI63011
# 2          PARKWAY SOUTH HIGH SCHOOL   1524889  ZI63021
# 3  RIVERVIEW GARDENS SR. HIGH SCHOOL    579881  ZI63137
# 4              ROOSEVELT HIGH SCHOOL    582008  ZI63118

# %%
# Set a variable for the school detail we want
school_details = []


# from the import of the csv file (done in cell above) - need OBInstID in either a list or df
# **NOTE using list temporarily to test
# OBInstID_list = ['577405','1524889']
OBInstID_list = latlon_df['OBInstlD'].tolist()

# Set School detail url
# sd_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/school/detail?id=00582204"
sd_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/school/detail?id="

# Loop over the list of IDs for each school and grab the detail information
for OBID in OBInstID_list:
    sd = requests.get(sd_url + str(OBID), headers={"accept":"application/json", "apikey":attom_data}).json()
    school = sd['school'][0]
    school_detail = school['SchoolProfileAndDistrictInfo']['SchoolDetail']
    school_details.append(school_detail)
    #print(sd)
    #print(base_url + OBID)
    

# Create a dataframe from the list of school detail info
school_details_df = pd.DataFrame(school_details)

# Add the school ID as a column to the df in case needed it later as a key for a merge
school_details_df["OBInstID"] = OBInstID_list

# %%
#print(OBInstID_list)
school_details_df.head()
# Out:
#   educationClimateIndex advancedPlacement beforeandafterschoolprgms  \
# 0         BELOW AVERAGE                 Y                         N
# 1         ABOVE AVERAGE                 Y                         Y
# 2         ABOVE AVERAGE                 Y                         N
# 3         BELOW AVERAGE                 N                         N
# 4                   LOW                 Y                         N
#
#   blueribbonschool charterschools giftedandtalented internationbaccalaureate  \
# 0                N              N                 N                        N
# 1                N              N                 Y                        N
# 2                N              N                 Y                        N
# 3                N              N                 N                        N
# 4                N              N                 N                        N
#
#   magnetschool sitebased  collegebound  ... adulteducationclasses adultother  \
# 0            N         N            91  ...                     N       None
# 1            N         N            98  ...                     N       None
# 2            N         Y            95  ...                     Y          Y
# 3            N         N            77  ...                     N       None
# 4            N         N            52  ...                     N       None
#
#   specialeducation alterantiveprogram yearroundclasses ESL  \
# 0                Y                  N                N   Y
# 1                Y                  N                N   N
# 2                Y                  N                N   Y
# 3                Y                  N                N   N
# 4                Y                  N                N   Y
#
#          Povertylevel Instructionalexpensepupil  AYPschool OBInstID
# 0    6 - 15.9 PERCENT                      5669          N   577405
# 1    6 - 15.9 PERCENT                      6840          N   579439
# 2    6 - 15.9 PERCENT                      6840          Y  1524889
# 3    6 - 15.9 PERCENT                      4795          N   579881
# 4  30 PERCENT OR MORE                      7305          N   582008
#
# [5 rows x 21 columns]

# %%
# Write the school details data to a csv
school_details_df.to_csv("..\Data\school_detail2.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Get the Real Estate sales data

# %%
# Grab the GeoID from the CSV we imported earlier (same CSV that also had school ID)
GeoID_list = latlon_df['GeoID'].tolist()
print(GeoID_list)
# Out:
# ['ZI63123', 'ZI63011', 'ZI63021', 'ZI63137', 'ZI63118', 'ZI63134', 'ZI63144', 'ZI63044', 'ZI63005', 'ZI63017', 'ZI63105', 'ZI63128', 'ZI63126', 'ZI63141', 'ZI63131', 'ZI63045', 'ZI63025', 'ZI63026', 'ZI63135', 'ZI63031', 'ZI63033', 'ZI63042', 'ZI63136', 'ZI63140', 'ZI63122', 'ZI63124', 'ZI63125', 'ZI63143', 'ZI63043', 'ZI63121', 'ZI63129', 'ZI63034', 'ZI63132', 'ZI63114', 'ZI63133', 'ZI63115', 'ZI63117', 'ZI63101', 'ZI63102', 'ZI63103', 'ZI63104', 'ZI63106', 'ZI63107', 'ZI63108', 'ZI63109', 'ZI63110', 'ZI63111', 'ZI63112', 'ZI63113', 'ZI63116', 'ZI63139', 'ZI63146', 'ZI63147', 'ZI63155', 'ZI63138', 'ZI63074', 'ZI63127', 'ZI63130', 'ZI63088', 'ZI63120', 'ZI63119', 'ZI63038', 'ZI63040']

# %%
# Getting the real estate data
# curl -X GET --header 'Accept: application/json' --header 'apikey: 736f1130096aa92549d800921bca8e8c' 'https://api.gateway.attomdata.com/propertyapi/v1.0.0/salestrend/snapshot?geoid=ZI63021&interval=yearly&startyear=2014&endyear=2018'

# import the csv file - need GeoID in either a list or df
# **NOTE using manual list temporarily to test
#GeoID_list = ['ZI63045']
GeoID_list = latlon_df['GeoID'].tolist()

# Set variables
sales_details2018 = []

# Set Real estate detail url
# re_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/salestrend/snapshot?geoid=ZI63021&interval=yearly&startyear=2014&endyear=2018"
re_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/salestrend/snapshot?interval=yearly&startyear=2014&endyear=2018&geoid="

# Loop over the list of GeoIDs representing each area and grab the sales trend information
try:
    for GeoID in GeoID_list:
        #re = requests.get(re_url + GeoID, headers={"accept":"application/json", "apikey":attom_data}).json()
        re = requests.get(re_url + str(GeoID), headers={"accept":"application/json", "apikey":attom_data}).json()
        sales2018 = re['salestrends'][4]
        sales_detail2018 = sales2018['SalesTrend']
        sales_details2018.append(sales_detail2018)
        #pprint(re)
        #print(base_url + GeoID)
# print(sales2014)
# print(sales2015)
except IndexError:
    print("IndexError on record: " + GeoID)
    sales_details2018.append({'homesalecount':'issue here', 'avgsaleprice':'issue here', 'medsaleprice':'issue here'})
    pass

# Create a df for the sales trend data
sales_details2018_df = pd.DataFrame(sales_details2018)

# Add the GeoID as a column to the df in case needed it later as a key for a merge
# sales_details2018_df["GeoID"] = GeoID_list

sales_details2018_df
# Out:
# IndexError on record: ZI63045
#    homesalecount avgsaleprice medsaleprice
# 0           1128       157649       145950
# 1            696       294492       280000
# 2           1025       251951       227500
# 3            356        67045        41725
# 4            605       146375       114000
# 5            177        58138        50000
# 6            319       238304       185000
# 7            174       163868       165000
# 8            342       614509       566750
# 9            791       370493       349750
# 10           320       703499       571500
# 11           521       257825       234500
# 12           333       221183       196000
# 13           364       458782       371000
# 14           335       662447       540000
# 15    issue here   issue here   issue here

# %% [markdown]
# ####  Errored out, so implemented error checking with try: except:
# ####  Printed the error (see above) & investigated to see what was going on.
# ####  Turns out that zip 63045 had no salestrend data - i.e. the call was successful, just no results.

# %%
GeoID_list = ['ZI63045']
re_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/salestrend/snapshot?interval=yearly&startyear=2018&endyear=2018&geoid="

# Loop over the list of GeoIDs representing each area and grab the sales trend information - for the past 5 years
for GeoID in GeoID_list:
    #re = requests.get(re_url + GeoID, headers={"accept":"application/json", "apikey":attom_data}).json()
    re = requests.get(re_url + str(GeoID), headers={"accept":"application/json", "apikey":attom_data}).json()
    
pprint(re)
# Out:
# {'salestrends': [],
#  'status': {'code': 1,
#             'msg': 'SuccessWithoutResult',
#             'total': 0,
#             'version': '1.0.0'}}

# %%
# No salestrend data for ZI63045 - so remove it from our list . . .
# Same thing happened with ZI63140, and ZI63155.  remove them too.
GeoID_list = latlon_df['GeoID'].tolist()
GeoID_list.remove('ZI63045')
GeoID_list.remove('ZI63140')
GeoID_list.remove('ZI63155')
#print(GeoID_list)

# Then try the process again:
# Reset output list
sales_details2018 = []

# Set Real estate detail url
# re_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/salestrend/snapshot?geoid=ZI63021&interval=yearly&startyear=2014&endyear=2018"
re_url = "https://api.gateway.attomdata.com/propertyapi/v1.0.0/salestrend/snapshot?interval=yearly&startyear=2014&endyear=2018&geoid="

# Loop over the list of GeoIDs representing each area and grab the sales trend information
#   Note to self - original plan 4 yrs of sales, but just have 1 for school, so go w/ 2018, i.e. index 4 (5th yr, 0 base)
try:
    for GeoID in GeoID_list:
        #re = requests.get(re_url + GeoID, headers={"accept":"application/json", "apikey":attom_data}).json()
        re = requests.get(re_url + str(GeoID), headers={"accept":"application/json", "apikey":attom_data}).json()
        sales2018 = re['salestrends'][4]
        sales_detail2018 = sales2018['SalesTrend']
        sales_details2018.append(sales_detail2018)
        
except IndexError:
    print("IndexError on record: " + GeoID)
    sales_details2018.append({'homesalecount':'issue here', 'avgsaleprice':'issue here', 'medsaleprice':'issue here'})
    pass

# Create a df for the sales trend data
sales_details2018_df = pd.DataFrame(sales_details2018)

# Add the GeoID as a column to the df in case needed it later as a key for a merge
sales_details2018_df["GeoID"] = GeoID_list

sales_details2018_df.head()
# Out:
#    homesalecount  avgsaleprice  medsaleprice    GeoID
# 0           1128      157649.0      145950.0  ZI63123
# 1            696      294492.0      280000.0  ZI63011
# 2           1025      251951.0      227500.0  ZI63021
# 3            356       67045.0       41725.0  ZI63137
# 4            605      146375.0      114000.0  ZI63118

# %%
# Write the sales trend data to csv
sales_details2018_df.to_csv("..\Data\sales2_details2018.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Cleanup
# #### Since we had to drop some zip codes due to no salestrend data, we also need to drop them from our school info.  Otherwise our samples will have different lengths and we won't be able to plot them against each other

# %%
# Need to remove 63045, 63140, and 63155 from school_details_df

# %%
latlon_df.head()
# Out:
#    Zip Codes                    Areas   Latitude  Longitude  \
# 0      63123                   Affton  38.558084 -90.327783
# 1      63011                  Ballwin  38.604451 -90.558879
# 2      63021                  Ballwin  38.557323 -90.535236
# 3      63137  Bellefontaine Neighbors  38.747943 -90.211357
# 4      63118              Benton Park  38.595062 -90.229156
#
#                      School District  OBInstlD    GeoID
# 0                 AFFTON HIGH SCHOOL    577405  ZI63123
# 1                   WEST HIGH SCHOOL    579439  ZI63011
# 2          PARKWAY SOUTH HIGH SCHOOL   1524889  ZI63021
# 3  RIVERVIEW GARDENS SR. HIGH SCHOOL    579881  ZI63137
# 4              ROOSEVELT HIGH SCHOOL    582008  ZI63118

# %%
# Pull the zip codes from the latlon df . . .
zip_list = latlon_df['Zip Codes'].tolist()

# Then add them (the zip codes) as a column to the School df so we can remove the 3 entries to match the real estate df
school_details_df["Zip_Codes"] = zip_list
school_details_df.tail()
# Out:
#    educationClimateIndex advancedPlacement beforeandafterschoolprgms  \
# 58               AVERAGE                 Y                         Y
# 59                   LOW                 Y                         N
# 60         ABOVE AVERAGE                 Y                         Y
# 61         ABOVE AVERAGE                 N                         Y
# 62         ABOVE AVERAGE                 Y                         N
#
#    blueribbonschool charterschools giftedandtalented internationbaccalaureate  \
# 58                N              N                 Y                        N
# 59                N              N                 N                        N
# 60                N              N                 Y                        N
# 61                N              N                 Y                        N
# 62                N              N                 Y                        N
#
#    magnetschool sitebased  collegebound  ... adultother specialeducation  \
# 58            N         N            94  ...          Y                Y
# 59            N         N            84  ...       None                Y
# 60            N         Y            96  ...          Y                Y
# 61            N         Y             0  ...          Y                Y
# 62            N         N            96  ...       None                Y
#
#    alterantiveprogram yearroundclasses ESL        Povertylevel  \
# 58                  N                N   Y    6 - 15.9 PERCENT
# 59                  N                N   N  30 PERCENT OR MORE
# 60                  N                N   Y    6 - 15.9 PERCENT
# 61                  N                N   Y    6 - 15.9 PERCENT
# 62                  N                N   Y    6 - 15.9 PERCENT
#
#    Instructionalexpensepupil AYPschool    OBInstID Zip_Codes
# 58                      7839         Y      580359     63088
# 59                      7305         N  5700081307     63120
# 60                      7081         N      580517     63119
# 61                      5763         N     4945866     63038
# 62                      5763         N      580036     63040
#
# [5 rows x 22 columns]

# %%
#To select rows whose column value is in list 
zipstoremove = [63045, 63140, 63155]
schIDtoremove_list = []
removal_list_df = latlon_df.loc[latlon_df['Zip Codes'].isin(zipstoremove)]
schIDtoremove_list = removal_list_df['OBInstlD'].tolist()
print(schIDtoremove_list)
# Out:
# [576803, 577546, 5700110953]

# %%
new_school_details_df = school_details_df[(school_details_df.Zip_Codes != 63045) & (school_details_df.Zip_Codes != 63140) & (school_details_df.Zip_Codes != 63155)]
new_school_details_df
# Out:
#    educationClimateIndex advancedPlacement beforeandafterschoolprgms  \
# 0          BELOW AVERAGE                 Y                         N
# 1          ABOVE AVERAGE                 Y                         Y
# 2          ABOVE AVERAGE                 Y                         N
# 3          BELOW AVERAGE                 N                         N
# 4                    LOW                 Y                         N
# 5          BELOW AVERAGE                 Y                         N
# 6          ABOVE AVERAGE                 Y                         N
# 7                AVERAGE                 N                         Y
# 8          ABOVE AVERAGE                 N                         Y
# 9          ABOVE AVERAGE                 Y                         N
# 10         ABOVE AVERAGE                 Y                         N
# 11               AVERAGE                 Y                         N
# 12          UNCLASSIFIED                 N                         N
# 13         ABOVE AVERAGE                 Y                         N
# 14         ABOVE AVERAGE                 N                         N
# 16               AVERAGE                 N                         N
# 17               AVERAGE                 Y                         N
# 18         BELOW AVERAGE                 Y                         Y
# 19         BELOW AVERAGE                 N                         N
# 20         BELOW AVERAGE                 Y                         N
# 21         BELOW AVERAGE                 Y                         N
# 22                   LOW                 N                         Y
# 24         ABOVE AVERAGE                 Y                         N
# 25         ABOVE AVERAGE                 Y                         Y
# 26         BELOW AVERAGE                 Y                         Y
# 27               AVERAGE                 N                         Y
# 28               AVERAGE                 N                         Y
# 29         BELOW AVERAGE                 Y                         Y
# 30               AVERAGE                 Y                         N
# 31         BELOW AVERAGE                 Y                         N
# 32         ABOVE AVERAGE                 N                         Y
# 33         BELOW AVERAGE                 Y                         N
# 34                   LOW                 N                         Y
# 35                   LOW                 N                         N
# 36               AVERAGE                 N                         Y
# 37                   LOW                 N                         Y
# 38               AVERAGE                 N                         Y
# 39          UNCLASSIFIED                 N                         N
# 40               AVERAGE                 Y                         Y
# 41                   LOW                 N                         Y
# 42                   LOW                 N                         N
# 43               AVERAGE                 Y                         N
# 44               AVERAGE                 N                         N
# 45               AVERAGE                 Y                         N
# 46                   LOW                 Y                         Y
# 47               AVERAGE                 Y                         N
# 48                   LOW                 N                         N
# 49               AVERAGE                 N                         N
# 50               AVERAGE                 Y                         N
# 51         ABOVE AVERAGE                 Y                         N
# 52                   LOW                 Y                         N
# 54         BELOW AVERAGE                 N                         N
# 55         BELOW AVERAGE                 Y                         N
# 56               AVERAGE                 Y                         N
# 57         ABOVE AVERAGE                 Y                         Y
# 58               AVERAGE                 Y                         Y
# 59                   LOW                 Y                         N
# 60         ABOVE AVERAGE                 Y                         Y
# 61         ABOVE AVERAGE                 N                         Y
# 62         ABOVE AVERAGE                 Y                         N
#
#    blueribbonschool charterschools giftedandtalented internationbaccalaureate  \
# 0                 N              N                 N                        N
# 1                 N              N                 Y                        N
# 2                 N              N                 Y                        N
# 3                 N              N                 N                        N
# 4                 N              N                 N                        N
# 5                 N              N                 Y                        N
# 6                 N              N                 Y                        N
# 7                 N              N                 N                        N
# 8                 N              N                 N                        N
# 9                 N              N                 Y                        N
# 10                N              N                 Y                        N
# 11                N              N                 Y                        Y
# 12                N              N                 N                        N
# 13                N              N                 Y                        N
# 14                N              N                 N                        N
# 16                N              N                 Y                        N
# 17                N              N                 Y                        N
# 18                N              N                 Y                        N
# 19                N              N                 Y                        N
# 20                N              N                 N                        N
# 21                N              N                 Y                        N
# 22                N              N                 Y                        N
# 24                N              N                 N                        N
# 25                N              N                 Y                        N
# 26                N              N                 N                        N
# 27                N              N                 N                        N
# 28                N              N                 N                        N
# 29                N              N                 Y                        N
# 30                N              N                 Y                        N
# 31                N              N                 N                        N
# 32                N              N                 Y                        N
# 33                N              N                 Y                        N
# 34                N              N                 N                        N
# 35                N              N                 N                        N
# 36                N              N                 N                        N
# 37                N              N                 N                        N
# 38                N              Y                 N                        N
# 39                N              Y                 N                        N
# 40                N              N                 Y                        N
# 41                N              N                 N                        N
# 42                N              N                 N                        N
# 43                N              N                 N                        Y
# 44                N              Y                 N                        N
# 45                N              N                 Y                        N
# 46                N              N                 N                        N
# 47                N              N                 N                        N
# 48                N              N                 N                        N
# 49                N              Y                 N                        N
# 50                N              N                 Y                        N
# 51                N              N                 Y                        N
# 52                N              N                 N                        N
# 54                N              N                 N                        N
# 55                N              N                 Y                        N
# 56                N              N                 Y                        Y
# 57                N              N                 Y                        N
# 58                N              N                 Y                        N
# 59                N              N                 N                        N
# 60                N              N                 Y                        N
# 61                N              N                 Y                        N
# 62                N              N                 Y                        N
#
#    magnetschool sitebased  collegebound  ... adultother specialeducation  \
# 0             N         N            91  ...       None                Y
# 1             N         N            98  ...       None                Y
# 2             N         Y            95  ...          Y                Y
# 3             N         N            77  ...       None                Y
# 4             N         N            52  ...       None                Y
# 5             N         N            85  ...       None                Y
# 6             N         N            96  ...       None                Y
# 7             N         N            87  ...          Y                Y
# 8             N         Y             0  ...       None                Y
# 9             N         N            96  ...       None                Y
# 10            N         N            99  ...          Y                Y
# 11            N         N            95  ...          Y                Y
# 12            N         N             0  ...       None                N
# 13            N         Y            97  ...          Y                Y
# 14            N         N            87  ...       None                Y
# 16            N         N            95  ...       None                Y
# 17            N         N            98  ...       None                Y
# 18            N         N            84  ...       None                Y
# 19            N         N             0  ...       None                Y
# 20            N         N            89  ...       None                Y
# 21            N         N            86  ...          Y                Y
# 22            N         N            85  ...       None                Y
# 24            N         N            97  ...       None                Y
# 25            N         N             0  ...          Y                Y
# 26            N         N            91  ...       None                Y
# 27            N         N            91  ...       None                Y
# 28            N         N            87  ...          Y                Y
# 29            N         N            84  ...       None                Y
# 30            N         N            97  ...          Y                Y
# 31            N         N            92  ...          Y                Y
# 32            N         N             0  ...       None                Y
# 33            N         N            85  ...       None                Y
# 34            N         N            73  ...       None                Y
# 35            Y         N            55  ...       None                Y
# 36            N         N            91  ...       None                Y
# 37            N         N           100  ...       None                N
# 38            N         N             0  ...       None                Y
# 39            N         N             0  ...       None                N
# 40            N         Y            92  ...       None                Y
# 41            N         N           100  ...       None                N
# 42            N         N            41  ...       None                Y
# 43            Y         Y           100  ...       None                N
# 44            N         N             0  ...       None                N
# 45            Y         N            84  ...       None                Y
# 46            N         N            96  ...       None                Y
# 47            Y         N            93  ...          Y                Y
# 48            Y         N            55  ...       None                Y
# 49            N         N             0  ...       None                N
# 50            Y         N            84  ...       None                Y
# 51            N         N            96  ...          Y                Y
# 52            N         N            84  ...       None                Y
# 54            N         N             0  ...       None                N
# 55            N         N            85  ...       None                Y
# 56            N         N            95  ...          Y                Y
# 57            N         Y            81  ...       None                Y
# 58            N         N            94  ...          Y                Y
# 59            N         N            84  ...       None                Y
# 60            N         Y            96  ...          Y                Y
# 61            N         Y             0  ...          Y                Y
# 62            N         N            96  ...       None                Y
#
#    alterantiveprogram yearroundclasses ESL        Povertylevel  \
# 0                   N                N   Y    6 - 15.9 PERCENT
# 1                   N                N   N    6 - 15.9 PERCENT
# 2                   N                N   Y    6 - 15.9 PERCENT
# 3                   N                N   N    6 - 15.9 PERCENT
# 4                   N                N   Y  30 PERCENT OR MORE
# 5                   Y                N   Y    6 - 15.9 PERCENT
# 6                   N                N   Y    6 - 15.9 PERCENT
# 7                   N                N   Y    6 - 15.9 PERCENT
# 8                   N                Y   N    6 - 15.9 PERCENT
# 9                   N                N   Y    6 - 15.9 PERCENT
# 10                  N                Y   Y    6 - 15.9 PERCENT
# 11                  N                N   Y    6 - 15.9 PERCENT
# 12                  N                N   N    6 - 15.9 PERCENT
# 13                  N                N   Y    6 - 15.9 PERCENT
# 14                  N                N   N    6 - 15.9 PERCENT
# 16                  N                N   Y    6 - 15.9 PERCENT
# 17                  N                N   Y    6 - 15.9 PERCENT
# 18                  N                N   N    6 - 15.9 PERCENT
# 19                  N                N   N    6 - 15.9 PERCENT
# 20                  N                N   N    6 - 15.9 PERCENT
# 21                  N                N   Y    6 - 15.9 PERCENT
# 22                  N                N   Y    6 - 15.9 PERCENT
# 24                  Y                N   Y    6 - 15.9 PERCENT
# 25                  N                N   Y    6 - 15.9 PERCENT
# 26                  N                N   Y    6 - 15.9 PERCENT
# 27                  N                N   N    6 - 15.9 PERCENT
# 28                  N                N   Y    6 - 15.9 PERCENT
# 29                  N                N   N    6 - 15.9 PERCENT
# 30                  N                N   Y    6 - 15.9 PERCENT
# 31                  N                N   N    6 - 15.9 PERCENT
# 32                  N                N   Y    6 - 15.9 PERCENT
# 33                  Y                N   Y    6 - 15.9 PERCENT
# 34                  N                N   N    6 - 15.9 PERCENT
# 35                  N                N   N  30 PERCENT OR MORE
# 36                  N                N   N    6 - 15.9 PERCENT
# 37                  N                N   N  30 PERCENT OR MORE
# 38                  N                N   N  30 PERCENT OR MORE
# 39                  N                N   N        NOT REPORTED
# 40                  N                N   N  30 PERCENT OR MORE
# 41                  N                N   N  30 PERCENT OR MORE
# 42                  N                N   N  30 PERCENT OR MORE
# 43                  N                Y   Y  30 PERCENT OR MORE
# 44                  N                N   N  30 PERCENT OR MORE
# 45                  N                N   N  30 PERCENT OR MORE
# 46                  N                N   N  30 PERCENT OR MORE
# 47                  N                N   Y  30 PERCENT OR MORE
# 48                  N                N   N  30 PERCENT OR MORE
# 49                  N                N   N  30 PERCENT OR MORE
# 50                  N                N   N  30 PERCENT OR MORE
# 51                  N                N   Y    6 - 15.9 PERCENT
# 52                  N                N   N  30 PERCENT OR MORE
# 54                  N                N   N    6 - 15.9 PERCENT
# 55                  Y                N   Y    6 - 15.9 PERCENT
# 56                  N                N   Y    6 - 15.9 PERCENT
# 57                  N                N   Y    6 - 15.9 PERCENT
# 58                  N                N   Y    6 - 15.9 PERCENT
# 59                  N                N   N  30 PERCENT OR MORE
# 60                  N                N   Y    6 - 15.9 PERCENT
# 61                  N                N   Y    6 - 15.9 PERCENT
# 62                  N                N   Y    6 - 15.9 PERCENT
#
#    Instructionalexpensepupil AYPschool    OBInstID Zip_Codes
# 0                       5669         N      577405     63123
# 1                       6840         N      579439     63011
# 2                       6840         Y     1524889     63021
# 3                       4795         N      579881     63137
# 4                       7305         N      582008     63118
# 5                       5227         N      579738     63134
# 6                       9590         Y      577625     63144
# 7                       7736         N      579544     63044
# 8                          0         N  5700078207     63005
# 9                       5763         N     4032500     63017
# 10                      9624         N      577675     63105
# 11                     16586         Y      578722     63128
# 12                     65011         N  5700103534     63126
# 13                      6840         N      579207     63141
# 14                     65011         N  5700085667     63131
# 16                      5763         N      579996     63025
# 17                      5763         N     4032512     63026
# 18                      6261         N      577546     63135
# 19                      5897         N      578136     63031
# 20                      6261         N      577900     63033
# 21                      5897         N      578148     63042
# 22                      4425         N      578291     63136
# 24                      7200         N      578447     63122
# 25                      7060         N      578576     63124
# 26                      5904         N      577986     63125
# 27                      5236         Y      578825     63143
# 28                      7736         N      579544     63043
# 29                      6261         N      577546     63121
# 30                      5404         N      578966     63129
# 31                      5897         N      578124     63034
# 32                      6945         N      580220     63132
# 33                      5227         N      579738     63114
# 34                      4897         N      579128     63133
# 35                      7305         N      581406     63115
# 36                      5236         Y      578825     63117
# 37                         0         N  5700076033     63101
# 38                      2689         N  5700091168     63102
# 39                      3425         N  5700110953     63103
# 40                      7305         Y      582204     63104
# 41                         0         N  5700076033     63106
# 42                      7305         N      581212     63107
# 43                      7305         Y      580830     63108
# 44                      3833         N  5700090181     63109
# 45                      7305         N     4018669     63110
# 46                      7305         Y     5280279     63111
# 47                      7305         Y     1759436     63112
# 48                      7305         N      581406     63113
# 49                      3833         N  5700090181     63116
# 50                      7305         N     4018669     63139
# 51                      6840         N      579348     63146
# 52                      7305         N  5700081307     63147
# 54                         0         N  5700074566     63138
# 55                      5227         N      579738     63074
# 56                     16586         Y      578722     63127
# 57                      6945         N      580311     63130
# 58                      7839         Y      580359     63088
# 59                      7305         N  5700081307     63120
# 60                      7081         N      580517     63119
# 61                      5763         N     4945866     63038
# 62                      5763         N      580036     63040
#
# [60 rows x 22 columns]

# %%
# Write the school details data to a csv
new_school_details_df.to_csv("..\Data\school_detail3.csv", encoding="utf-8", index=False)
